# %%
import pandas as pd 
import numpy as np  
import matplotlib.pyplot as plt  
import random

# %% [markdown]
# Combination choose

# %%
choice = 0
figure = [["DAVIS","AUC"],["DAVIS","AUPR"],["KIBA","AUC"],["KIBA","AUPR"]]

Xline = ["Bi-interaction,MLP", "Bi-interaction,GCN", "GCN,MLP", "GCN,GCN"]

Yline = [[0.8876,0.9078, 0.8861, 0.8921],
        [0.9880 ,0.9903, 0.9878, 0.9881],
        [0.8782, 0.8919, 0.9024, 0.9081],
        [0.7056, 0.7390, 0.7571, 0.7692]]

# %%
all_colors = list(plt.cm.colors.cnames.keys())
random.seed(23)
c = random.choices(all_colors, k=4)
c = ['#ee6a5b','#f6b654',"#c7dbd5","#4ea59f"]
# fig, ax = plt.subplots(nrows=2, ncols=2)
# plot1 = plt.subplot2grid((4, 4), (0, 0), rowspan=2)
# plot2 = plt.subplot2grid((4, 4), (0, 2), rowspan=2)
# plot3 = plt.subplot2grid((4, 4), (2, 0), rowspan=2)
# plot4 = plt.subplot2grid((4, 4), (2, 2), rowspan=2)
plt.figure(figsize=(10,8),dpi=100)
for choice in range(4):
#     plt.figure(figsize=(3,2), dpi= 150)
    plt.subplot(2,2,choice+1)

    plt.barh( Xline, Yline[choice] , edgecolor = c,\
            linewidth = 0.2, align = 'center', color = c, ecolor = c)
#     for i, val in enumerate(Yline):
#         plt.text(val, i, float(val), fontdict={'fontweight':500, 'size':12},transform=ax.transAxes)

    plt.title("Choice of <CrossInteraction,Sub-Interaction>", fontsize=11)
    plt.ylabel(figure[choice][0],fontsize=12)
    plt.xlabel(figure[choice][1],fontsize=12)
    plt.xlim(left = min(Yline[choice])-0.01,right = max(Yline[choice])+0.01)
#     plt.savefig('./figure/feature_importance-{}.png'.format(choice + 1),dpi=600, bbox_inches='tight')
#     plt.subplot(2,2,choice+1)
plt.subplots_adjust(left=None, bottom=None, right=None, top=None,
                wspace=0.8, hspace=0.5)
plt.savefig('./figure/combination.png',dpi=600, bbox_inches='tight')
plt.show()
    
# plt.savefig('./figure/feature_importance.png',dpi=600, bbox_inches='tight')
# plt.savefig('./figure/feature_importance-{}.png'.format(choice + 1),dpi=600, bbox_inches='tight')

# %% [markdown]
# ### COLD START

# %%
import matplotlib.pyplot as plt
import numpy as np

# 设置显示中文
# plt.rcParams['font.sans-serif'] = ['SimHei'] # 指定默认字体 
# plt.rcParams['axes.unicode_minus']=False     # 正常显示负号

#设置画布大小像素点
plt.figure(figsize=(10,15),dpi=100)
# plt.figure(figsize=(10, 4))

totalWidth=0.8 
labelNums=2 
barWidth=totalWidth/labelNums 
seriesNums=3 
name=['GENNDTI','GraphDTA','GCN']

# # 绘制直方图
# plt.subplot(4,2,1)

# l1=[0.9078,0.7228,0.8900]
# l2=[0.9903,0.9272,0.9884]
# b = plt.bar([x for x in range(seriesNums)], height=l1, label="AUC",color='sandybrown',width=barWidth)
# a = plt.bar([x+barWidth for x in range(seriesNums)], height=l2, label="AUPR", color = 'lightsteelblue',width=barWidth)
# plt.xticks([x+barWidth/2*(labelNums-1) for x in range(seriesNums)], name)
# autolabel(a)
# autolabel(b)  

# plt.ylabel("Score")
# plt.ylim((min(min(l1),min(l2))-0.05),(max(max(l1),max(l2))+0.2))
# plt.title("Davis_S1")
# plt.legend()


# # 绘制条形图
# plt.subplot(4,2,2)

# l1=[0.9081,0.91807,0.8798]
# l2=[0.7692,0.7951,0.7185]

# b = plt.bar([x for x in range(seriesNums)], height=l1, label="AUC",color='sandybrown',width=barWidth)
# a = plt.bar([x+barWidth for x in range(seriesNums)], height=l2, label="AUPR", color = 'lightsteelblue',width=barWidth)
# plt.xticks([x+barWidth/2*(labelNums-1) for x in range(seriesNums)], name)
# autolabel(a)
# autolabel(b)  

# plt.ylabel("Score")
# plt.ylim((min(min(l1),min(l2))-0.05),(max(max(l1),max(l2))+0.1))
# plt.title("KIBA_S1")
# plt.legend()




# 绘制条形图
plt.subplot(3,2,1)


l1=[0.7083,0.5119,0.6331]
l2=[0.9632,0.8736,0.9483]

b = plt.bar([x for x in range(seriesNums)], height=l1, label="AUC",color='#f6b654',width=barWidth)
a = plt.bar([x+barWidth for x in range(seriesNums)], height=l2, label="AUPR", color = '#4ea59f',width=barWidth)
plt.xticks([x+barWidth/2*(labelNums-1) for x in range(seriesNums)], name)
autolabel(a)
autolabel(b)  

plt.ylabel("Score")
plt.ylim((min(min(l1),min(l2))-0.05),(max(max(l1),max(l2))+0.15))
plt.title("Davis_S2")
plt.legend()


# 绘制条形图
plt.subplot(3,2,2)


l1=[0.6583,0.8511,0.6538]
l2=[0.3419,0.6816,0.3215]

# b = plt.bar([x for x in range(seriesNums)], height=l1, label="AUC",color='sandybrown',width=barWidth)
# a = plt.bar([x+barWidth for x in range(seriesNums)], height=l2, label="AUPR", color = 'lightsteelblue',width=barWidth)

b = plt.bar([x for x in range(seriesNums)], height=l1, label="AUC",color='#f6b654',width=barWidth)
a = plt.bar([x+barWidth for x in range(seriesNums)], height=l2, label="AUPR", color = '#4ea59f',width=barWidth)
plt.xticks([x+barWidth/2*(labelNums-1) for x in range(seriesNums)], name)
autolabel(a)
autolabel(b)  

plt.ylabel("Score")
plt.ylim((min(min(l1),min(l2))-0.05),(max(max(l1),max(l2))+0.15))
plt.title("KIBA_S2")
plt.legend()


plt.subplot(3,2,3)


l1=[0.7699,0.7104,0.7679]
l2=[0.9714,0.9264,0.9718]

b = plt.bar([x for x in range(seriesNums)], height=l1, label="AUC",color='#f6b654',width=barWidth)
a = plt.bar([x+barWidth for x in range(seriesNums)], height=l2, label="AUPR", color = '#4ea59f',width=barWidth)
plt.xticks([x+barWidth/2*(labelNums-1) for x in range(seriesNums)], name)
autolabel(a)
autolabel(b)  

plt.ylabel("Score")
plt.ylim((min(min(l1),min(l2))-0.05),(max(max(l1),max(l2))+0.15))
plt.title("Davis_S3")
plt.legend()



plt.subplot(3,2,4)


l1=[0.7722,0.7285,0.7538]
l2=[0.4929,0.4897,0.4722]

b = plt.bar([x for x in range(seriesNums)], height=l1, label="AUC",color='#f6b654',width=barWidth)
a = plt.bar([x+barWidth for x in range(seriesNums)], height=l2, label="AUPR", color = '#4ea59f',width=barWidth)
plt.xticks([x+barWidth/2*(labelNums-1) for x in range(seriesNums)], name)
autolabel(a)
autolabel(b)  

plt.ylabel("Score")
plt.ylim((min(min(l1),min(l2))-0.05),(max(max(l1),max(l2))+0.15))
plt.title("KIBA_S3")
plt.legend()



plt.subplot(3,2,5)


l1=[0.5766,0.7166, 0.5074]
l2=[0.9427,0.9251, 0.9256]

b = plt.bar([x for x in range(seriesNums)], height=l1, label="AUC",color='#f6b654',width=barWidth)
a = plt.bar([x+barWidth for x in range(seriesNums)], height=l2, label="AUPR", color = '#4ea59f',width=barWidth)
plt.xticks([x+barWidth/2*(labelNums-1) for x in range(seriesNums)], name)
autolabel(a)
autolabel(b)  

plt.ylabel("Score")
plt.ylim((min(min(l1),min(l2))-0.05),(max(max(l1),max(l2))+0.15))
plt.title("Davis_S4")
plt.legend()



plt.subplot(3,2,6)

l1=[0.4814,0.6605,0.5019]
l2=[0.1991,0.3692,0.2151]

b = plt.bar([x for x in range(seriesNums)], height=l1, label="AUC",color='#f6b654',width=barWidth)
a = plt.bar([x+barWidth for x in range(seriesNums)], height=l2, label="AUPR", color = '#4ea59f',width=barWidth)
plt.xticks([x+barWidth/2*(labelNums-1) for x in range(seriesNums)], name)
autolabel(a)
autolabel(b)  

plt.ylabel("Score")
plt.ylim((min(min(l1),min(l2))-0.05),(max(max(l1),max(l2))+0.15))
plt.title("KIBA_S4")
plt.legend()

plt.savefig('./figure/Cold_Start.png',dpi=600, bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import random
# 设置显示中文
# plt.rcParams['font.sans-serif'] = ['SimHei'] # 指定默认字体 
# plt.rcParams['axes.unicode_minus']=False     # 正常显示负号

#设置画布大小像素点
# plt.figure(figsize=(10,1),dpi=100)

all_colors = list(plt.cm.colors.cnames.keys())
random.seed(100)
c = random.choices(all_colors, k=10)

choice = 0
figure = [["ARCH","R-SQUARE"],["GARCH","R-SQUARE"],["SVM-RBF","R-SQUARE"],["SVM-LINEAR","R-SQUARE"]]

Xline = ["50/50", "60/40", "70/30", "90/10"]

Yline = [[0.8765,0.8733,0.9047,0.9078],
        [0.9866,0.9850,0.9901,0.9903],
        [0.8716,0.9043,0.8799,0.9081],
        [0.6996,0.7615,0.7154,0.7692]]

plt.figure(figsize=(10,8),dpi=100)

# fig, ax = plt.subplots(figsize=(16,10), dpi= 80)
# ax.hlines(y=Yline[1], xmin=11, xmax=26, color='gray', alpha=0.7, linewidth=1, linestyles='dashdot')
# ax.scatter(y=Yline[1], x=Xline, s=75, color='firebrick', alpha=0.7)
# plt.show()

for choice in range(4):
    plt.subplot(2,2,choice+1)
#     plt.plot(Xline, Yline[choice],label='小龙虾价格')
    plt.plot(Yline[choice],Xline,lw=3.0,ls="--",marker='o',mfc='orange',color = 'firebrick')

#     plt.plot( Xline, Yline[choice] , edgecolor = c,\
#             linewidth = 0.6, align = 'center', color = c, ecolor = c)

    #     for i, val in enumerate(Yline):
#         plt.text(val, i, float(val), fontdict={'fontweight':500, 'size':12},transform=ax.transAxes)

    plt.title("", fontsize=11)
    plt.ylabel(figure[choice][0],fontsize=12)
    plt.xlabel(figure[choice][1],fontsize=12)
    plt.xlim(left = min(Yline[choice])-0.01,right = max(Yline[choice])+0.003)
#     plt.savefig(''.format(choice + 1),dpi=600, bbox_inches='tight')
#     plt.subplot(2,2,choice+1)
# fig,axes = plt.subplots(3,2,sharey=True)
plt.subplots_adjust(left=None, bottom=None, right=None, top=None,
                wspace=0.5, hspace=0.5)

                    
plt.savefig('./figure/Attr.png',dpi=600, bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt
from pylab import *         #支持中文
mpl.rcParams['font.sans-serif'] = ['SimHei']
#定义函数来显示柱状上的数值
def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        plt.text(rect.get_x()+rect.get_width()/2.-0.2, 1.03*height, '%s' % float(height))
        
if __name__ == '__main__': 
    l1=[68, 96, 85, 86, 76,87, 95]
    l2=[85, 68, 79, 89, 94, 82,90]
    name=['A','B','C','D','E','F','E']
    total_width, n = 0.8, 2  
    width = total_width / n 
    x=[0,1,2,3,4,5,6]    
    a=plt.bar(x, l1, width=width, label='数学',fc = 'y')  
    for i in range(len(x)):  
        x[i] = x[i] + width  
    b=plt.bar(x, l2, width=width, label='语文',tick_label = name,fc = 'r',color='firebrick')   
    autolabel(a)
    autolabel(b)  
    plt.xlabel('Davis')
    plt.ylabel('score')
    plt.title('student score')
    plt.legend()
    plt.show()
# Out:
# /Users/yangby/opt/anaconda3/envs/yangby/lib/python3.7/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/yangby/opt/anaconda3/envs/yangby/lib/python3.7/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 23398 (\N{CJK UNIFIED IDEOGRAPH-5B66}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/yangby/opt/anaconda3/envs/yangby/lib/python3.7/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 35821 (\N{CJK UNIFIED IDEOGRAPH-8BED}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/yangby/opt/anaconda3/envs/yangby/lib/python3.7/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 25991 (\N{CJK UNIFIED IDEOGRAPH-6587}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
df_raw = pd.read_csv("https://github.com/selva86/datasets/raw/master/mpg_ggplot2.csv")

df_raw
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 0    compact
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# ..       ...
# ...

# %%
# # Prepare Data
df = df_raw.groupby('manufacturer').size().reset_index(name='counts')
n = df['manufacturer'].unique().__len__()+1
all_colors = list(plt.cm.colors.cnames.keys())
random.seed(100)
c = random.choices(all_colors, k=n)

# Plot Bars
plt.figure(figsize=(16,10), dpi= 80)
plt.bar(df['manufacturer'], df['counts'], color=c, width=.5)
for i, val in enumerate(df['counts'].values):
    plt.text(i, val, float(val), horizontalalignment='center', verticalalignment='bottom', fontdict={'fontweight':500, 'size':12})

# Decoration
plt.gca().set_xticklabels(df['manufacturer'], rotation=60, horizontalalignment= 'right')
plt.title("Number of Vehicles by Manaufacturers", fontsize=22)
plt.ylabel('# Vehicles')
plt.ylim(0, 45)
plt.show()
# Out:
# /Users/yangby/opt/anaconda3/envs/yangby/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: FixedFormatter should only be used together with FixedLocator
#   from ipykernel import kernelapp as app

# %%
# Prepare Data
df = df_raw[['cty', 'manufacturer']].groupby('manufacturer').apply(lambda x: x.mean())
df.sort_values('cty', inplace=True)
df.reset_index(inplace=True)

# Draw plot
import matplotlib.patches as patches

fig, ax = plt.subplots(figsize=(16,10), facecolor='white', dpi= 80)
ax.vlines(x=df.index, ymin=0, ymax=df.cty, color='firebrick', alpha=0.7, linewidth=20)

# Annotate Text
for i, cty in enumerate(df.cty):
    ax.text(i, cty+0.5, round(cty, 1), horizontalalignment='center')


# Title, Label, Ticks and Ylim
ax.set_title('Bar Chart for Highway Mileage', fontdict={'size':22})
ax.set(ylabel='Miles Per Gallon', ylim=(0, 30))
plt.xticks(df.index, df.manufacturer.str.upper(), rotation=60, horizontalalignment='right', fontsize=12)

# Add patches to color the X axis labels
p1 = patches.Rectangle((.57, -0.005), width=.33, height=.13, alpha=.1, facecolor='green', transform=fig.transFigure)
p2 = patches.Rectangle((.124, -0.005), width=.446, height=.13, alpha=.1, facecolor='red', transform=fig.transFigure)
fig.add_artist(p1)
fig.add_artist(p2)
plt.show()
